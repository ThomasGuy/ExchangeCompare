# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
dataDir = 'thursday'
bch = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\bchbtc.csv')
eos = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\eosbtc.csv')
etc = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\etcbtc.csv')
eth = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\ethbtc.csv')
ltc = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\ltcbtc.csv')
neo = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\neobtc.csv')
omg = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\omgbtc.csv')
xlm = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\xlmbtc.csv')
xrp = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\xrpbtc.csv')
zec = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\zecbtc.csv')
iota = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\iotabtc.csv')
dash = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\dashbtc.csv')
zil = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\zilbtc.csv')
zrx = pd.read_csv(f'.\\ticker\\data\\{dataDir}\\zrxbtc.csv')

# %%
pd.set_option('precision', 9)

# bch['Timestamp'] = pd.to_datetime(bch['Timestamp'], unit='s')
# bch.set_index('Timestamp', inplace=True)
# bch['diff_%'] = (100 * (bch.max(axis=1) - bch.min(axis=1))) / bch.max(axis=1)

eos['Timestamp'] = pd.to_datetime(eos['Timestamp'], unit='s')
eos.set_index('Timestamp', inplace=True)
eos['diff_%'] = (100 * (eos.max(axis=1) - eos.min(axis=1))) / eos.max(axis=1)

etc['Timestamp'] = pd.to_datetime(etc['Timestamp'], unit='s')
etc.set_index('Timestamp', inplace=True)
etc['diff_%'] = (100 * (etc.max(axis=1) - etc.min(axis=1))) / etc.max(axis=1)

eth['Timestamp'] = pd.to_datetime(eth['Timestamp'], unit='s')
eth.set_index('Timestamp', inplace=True)
eth['diff_%'] = (100 * (eth.max(axis=1) - eth.min(axis=1))) / eth.max(axis=1)

ltc['Timestamp'] = pd.to_datetime(ltc['Timestamp'], unit='s')
ltc.set_index('Timestamp', inplace=True)
ltc['diff_%'] = (100 * (ltc.max(axis=1) - ltc.min(axis=1))) / ltc.max(axis=1)

neo['Timestamp'] = pd.to_datetime(neo['Timestamp'], unit='s')
neo.set_index('Timestamp', inplace=True)
neo['diff_%'] = (100 * (neo.max(axis=1) - neo.min(axis=1))) / neo.max(axis=1)

omg['Timestamp'] = pd.to_datetime(omg['Timestamp'], unit='s')
omg.set_index('Timestamp', inplace=True)
omg['diff_%'] = (100 * (omg.max(axis=1) - omg.min(axis=1))) / omg.max(axis=1)

xlm['Timestamp'] = pd.to_datetime(xlm['Timestamp'], unit='s')
xlm.set_index('Timestamp', inplace=True)
xlm['diff_%'] = (100 * (xlm.max(axis=1) - xlm.min(axis=1))) / xlm.max(axis=1)

xrp['Timestamp'] = pd.to_datetime(xrp['Timestamp'], unit='s')
xrp.set_index('Timestamp', inplace=True)
xrp['diff_%'] = (100 * (xrp.max(axis=1) - xrp.min(axis=1))) / xrp.max(axis=1)

zec['Timestamp'] = pd.to_datetime(zec['Timestamp'], unit='s')
zec.set_index('Timestamp', inplace=True)
zec['diff_%'] = (100 * (zec.max(axis=1) - zec.min(axis=1))) / zec.max(axis=1)

iota['Timestamp'] = pd.to_datetime(iota['Timestamp'], unit='s')
iota.set_index('Timestamp', inplace=True)
iota['diff_%'] = (100 * (iota.max(axis=1) - iota.min(axis=1))) / iota.max(axis=1)

dash['Timestamp'] = pd.to_datetime(dash['Timestamp'], unit='s')
dash.set_index('Timestamp', inplace=True)
dash['diff_%'] = (100 * (dash.max(axis=1) - dash.min(axis=1))) / dash.max(axis=1)

zil['Timestamp'] = pd.to_datetime(zil['Timestamp'], unit='s')
zil.set_index('Timestamp', inplace=True)
zil['diff_%'] = (100 * (zil.max(axis=1) - zil.min(axis=1))) / zil.max(axis=1)

zrx['Timestamp'] = pd.to_datetime(zrx['Timestamp'], unit='s')
zrx.set_index('Timestamp', inplace=True)
zrx['diff_%'] = (100 * (zrx.max(axis=1) - zrx.min(axis=1))) / zrx.max(axis=1)

# %%
omg.drop(['diff_%'], axis=1).plot(figsize=(16,6),title='Dash');

# %%
etc.drop(['diff_%'], axis=1).plot(figsize=(16,6),title='Ethereum Classic');

# %%
eth['diff_%'].plot.hist(figsize=(16,4),bins=20,label='eth');
etc['diff_%'].plot.hist(figsize=(16,4),bins=20,label='etc');
eos['diff_%'].plot.hist(figsize=(16,4),bins=20,label='eos');
bch['diff_%'].plot.hist(figsize=(16,4),bins=20,label='bch');
neo['diff_%'].plot.hist(figsize=(16,4),bins=20,label='neo');
omg['diff_%'].plot.hist(figsize=(16,4),bins=20,label='omg');
ltc['diff_%'].plot.hist(figsize=(16,4),bins=20,label='ltc');
xlm['diff_%'].plot.hist(figsize=(16,4),bins=20,label='xlm');
xrp['diff_%'].plot.hist(figsize=(16,4),bins=20,label='xrp');
zec['diff_%'].plot.hist(figsize=(16,4),bins=20,label='zec');
iota['diff_%'].plot.hist(figsize=(16,4),bins=20,label='iota');
dash['diff_%'].plot.hist(figsize=(16,4),bins=20,label='dash');
zil['diff_%'].plot.hist(figsize=(16,4),bins=20,label='zil');
zrx['diff_%'].plot.hist(figsize=(16,4),bins=20,label='zrx');
plt.legend()

# %%
omg['diff_%'].plot(figsize=(12,4));

# %%
omg['diff_%'].plot.hist(figsize=(12,4),bins=50,label='omg');

# %%
eth['diff_%'].plot(figsize=(12,4));

# %%
etc['diff_%'].plot.hist(figsize=(12,4),bins=20,label='zil');

# %%
zil = zil.dropna(subset=['Bitfinex'], how='all')

# %%
ltc[['Bitfinex','Bittrex','Huboi','Binance','Kraken','Kucoin','Poloniex','Cex']].plot(figsize=(8,6))

# %%
zil_clean = zil[type(['Bitfinex']) is nor str]
# Out:
#   File "<ipython-input-53-942ae4c38949>", line 1
#     zil_clean = zil[type(['Bitfinex']) is nor str]
#                                                 ^
# SyntaxError: invalid syntax

# %%
100 * (omg['Cex'].iloc[50] - omg['Cex'].iloc[50]) / omg['Cex'].iloc[50]

# %%
omg.plot()
